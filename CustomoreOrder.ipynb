# %%
#Import requirements library
import pandas as pd
import numpy as np

# %% [markdown]
# 1. READ DATA

# %%
#Read excel data
order = pd.read_excel("Sample_Customore_Order_raw.xlsx", sheet_name='raw')

# %%
#View Sample Customore Order
order
# Out:
#        customer_unique_id    order_id  item_quantity created_day  \
# 0                       1  A000000001              1  2019-07-01
# 1                       2  A000000002              1  2019-07-01
# 2                       3  A000000003              1  2019-07-01
# 3                       4  A000000004              1  2019-07-01
# 4                       5  A000000005              1  2019-07-01
# ...                   ...         ...            ...         ...
# 61723               30091  A000037831              1  2019-07-30
# 61724               30511  A000037832              1  2019-07-30
# 61725               30512  A000037833              1  2019-07-30
# 61726               30513  A000037834              1  2019-07-30
# 61727               30060  A000037835              1  2019-07-30
#
#        onsite_original_price  selling_price  shipping_fee  voucher_platform  \
# 0                     338000         259000          3000                 0
# 1                     175000         139000             0                 0
# 2                     520000         359000         14927                 0
# 3                     238000         185000         29645                 0
# 4                     159000         129000         14927                 0
# ...                      ...            ...           ...               ...
# 61723                 155000         119000         10000                 0
# 61724                 475000         399000         10000                 0
# 61725                 135000          99000         35641                 0
# 61726                 350000         209000             0                 0
# 61727                 215000         165000             0                 0
#
#        voucher_seller                    payment_method order_status
# 0                   0                       Airpay GIRO    CANCELLED
# 1                   0                  Cash on Delivery    COMPLETED
# 2                   0                       Cybersource    COMPLETED
# 3                   0                  Cash on Delivery    COMPLETED
# 4                   0                  Cash on Delivery    CANCELLED
# ...               ...                               ...          ...
# 61723               0                  Cash on Delivery    COMPLETED
# 61724               0                  Cash on Delivery    COMPLETED
# 61725               0                  Cash on Delivery    COMPLETED
# 61726               0  VN Airpay Ibanking (Techcombank)    CANCELLED
# 61727               0                  Cash on Delivery    COMPLETED
#
# [61728 rows x 11 columns]

# %% [markdown]
# 2. PRE-PROCESSING DATA

# %%
#Checking dataset shape
order.shape
# Out:
# (61728, 11)

# %%
#Describe dataset
order.describe()
# Out:
#        customer_unique_id  item_quantity  onsite_original_price  \
# count        61728.000000   61728.000000           6.172800e+04
# mean         14323.092260       1.111748           2.347072e+05
# std           8050.804821       1.487318           1.574884e+05
# min              1.000000       1.000000           1.000000e+03
# 25%           7954.000000       1.000000           1.500000e+05
# 50%          13852.500000       1.000000           1.950000e+05
# 75%          20361.250000       1.000000           2.580000e+05
# max          30513.000000     198.000000           1.750000e+06
#
#        selling_price   shipping_fee  voucher_platform  voucher_seller
# count   6.172800e+04   61728.000000           61728.0         61728.0
# mean    1.514818e+05   11191.105689               0.0             0.0
# std     1.178384e+05   16157.498442               0.0             0.0
# min     0.000000e+00       0.000000               0.0             0.0
# 25%     8.900000e+04       0.000000               0.0             0.0
# 50%     1.250000e+05    3000.000000               0.0             0.0
# 75%     1.790000e+05   16000.000000               0.0             0.0
# max     1.579000e+06  384500.000000               0.0             0.0

# %%
#Create new dataset base on order
newOrder = order.copy()
newOrder.head(10)
# Out:
#    customer_unique_id    order_id  item_quantity created_day  \
# 0                   1  A000000001              1  2019-07-01
# 1                   2  A000000002              1  2019-07-01
# 2                   3  A000000003              1  2019-07-01
# 3                   4  A000000004              1  2019-07-01
# 4                   5  A000000005              1  2019-07-01
# 5                   6  A000000006              1  2019-07-01
# 6                   7  A000000007              1  2019-07-01
# 7                   7  A000000007              1  2019-07-01
# 8                   8  A000000008              1  2019-07-01
# 9                   9  A000000009              1  2019-07-01
#
#    onsite_original_price  selling_price  shipping_fee  voucher_platform  \
# 0                 338000         259000          3000                 0
# 1                 175000         139000             0                 0
# 2                 520000         359000         14927                 0
# 3                 238000         185000         29645                 0
# 4                 159000         129000         14927                 0
# 5                 135000         105000             0                 0
# 6                 159000         129000          3000                 0
# 7                 248000         209000          3000                 0
# 8                 199000         169000         40297                 0
# 9                 198000         169000             0                 0
#
#    voucher_seller    payment_method order_status
# 0               0       Airpay GIRO    CANCELLED
# 1               0  Cash on Delivery    COMPLETED
# 2               0       Cybersource    COMPLETED
# 3               0  Cash on Delivery    COMPLETED
# 4               0  Cash on Delivery    CANCELLED
# 5               0  Cash on Delivery    COMPLETED
# 6               0  Cash on Delivery    COMPLETED
# 7               0  Cash on Delivery    COMPLETED
# 8               0  Cash on Delivery    CANCELLED
# 9               0  Cash on Delivery    CANCELLED

# %%
#Create weekday column
weekdayList = []
for i in range(len(newOrder)):
    weekdayList.append(newOrder.created_day[i].day_name())

newOrder["weekday"] = weekdayList
#Print newOrder after adding weekday column
newOrder.head(10)
# Out:
#    customer_unique_id    order_id  item_quantity created_day  \
# 0                   1  A000000001              1  2019-07-01
# 1                   2  A000000002              1  2019-07-01
# 2                   3  A000000003              1  2019-07-01
# 3                   4  A000000004              1  2019-07-01
# 4                   5  A000000005              1  2019-07-01
# 5                   6  A000000006              1  2019-07-01
# 6                   7  A000000007              1  2019-07-01
# 7                   7  A000000007              1  2019-07-01
# 8                   8  A000000008              1  2019-07-01
# 9                   9  A000000009              1  2019-07-01
#
#    onsite_original_price  selling_price  shipping_fee  voucher_platform  \
# 0                 338000         259000          3000                 0
# 1                 175000         139000             0                 0
# 2                 520000         359000         14927                 0
# 3                 238000         185000         29645                 0
# 4                 159000         129000         14927                 0
# 5                 135000         105000             0                 0
# 6                 159000         129000          3000                 0
# 7                 248000         209000          3000                 0
# 8                 199000         169000         40297                 0
# 9                 198000         169000             0                 0
#
#    voucher_seller    payment_method order_status weekday
# 0               0       Airpay GIRO    CANCELLED  Monday
# 1               0  Cash on Delivery    COMPLETED  Monday
# 2               0       Cybersource    COMPLETED  Monday
# 3               0  Cash on Delivery    COMPLETED  Monday
# 4               0  Cash on Delivery    CANCELLED  Monday
# 5               0  Cash on Delivery    COMPLETED  Monday
# 6               0  Cash on Delivery    COMPLETED  Monday
# 7               0  Cash on Delivery    COMPLETED  Monday
# 8               0  Cash on Delivery    CANCELLED  Monday
# 9               0  Cash on Delivery    CANCELLED  Monday

# %%
newOrder["sale_percent"] = round(100-(newOrder["selling_price"]/newOrder["onsite_original_price"]*100))
newOrder.head(10)
# Out:
#    customer_unique_id    order_id  item_quantity created_day  \
# 0                   1  A000000001              1  2019-07-01
# 1                   2  A000000002              1  2019-07-01
# 2                   3  A000000003              1  2019-07-01
# 3                   4  A000000004              1  2019-07-01
# 4                   5  A000000005              1  2019-07-01
# 5                   6  A000000006              1  2019-07-01
# 6                   7  A000000007              1  2019-07-01
# 7                   7  A000000007              1  2019-07-01
# 8                   8  A000000008              1  2019-07-01
# 9                   9  A000000009              1  2019-07-01
#
#    onsite_original_price  selling_price  shipping_fee  voucher_platform  \
# 0                 338000         259000          3000                 0
# 1                 175000         139000             0                 0
# 2                 520000         359000         14927                 0
# 3                 238000         185000         29645                 0
# 4                 159000         129000         14927                 0
# 5                 135000         105000             0                 0
# 6                 159000         129000          3000                 0
# 7                 248000         209000          3000                 0
# 8                 199000         169000         40297                 0
# 9                 198000         169000             0                 0
#
#    voucher_seller    payment_method order_status weekday  sale_percent
# 0               0       Airpay GIRO    CANCELLED  Monday          23.0
# 1               0  Cash on Delivery    COMPLETED  Monday          21.0
# 2               0       Cybersource    COMPLETED  Monday          31.0
# 3               0  Cash on Delivery    COMPLETED  Monday          22.0
# 4               0  Cash on Delivery    CANCELLED  Monday          19.0
# 5               0  Cash on Delivery    COMPLETED  Monday          22.0
# 6               0  Cash on Delivery    COMPLETED  Monday          19.0
# 7               0  Cash on Delivery    COMPLETED  Monday          16.0
# 8               0  Cash on Delivery    CANCELLED  Monday          15.0
# 9               0  Cash on Delivery    CANCELLED  Monday          15.0

# %%
newOrder.describe()
# Out:
#        customer_unique_id  item_quantity  onsite_original_price  \
# count        61728.000000   61728.000000           6.172800e+04
# mean         14323.092260       1.111748           2.347072e+05
# std           8050.804821       1.487318           1.574884e+05
# min              1.000000       1.000000           1.000000e+03
# 25%           7954.000000       1.000000           1.500000e+05
# 50%          13852.500000       1.000000           1.950000e+05
# 75%          20361.250000       1.000000           2.580000e+05
# max          30513.000000     198.000000           1.750000e+06
#
#        selling_price   shipping_fee  voucher_platform  voucher_seller  \
# count   6.172800e+04   61728.000000           61728.0         61728.0
# mean    1.514818e+05   11191.105689               0.0             0.0
# std     1.178384e+05   16157.498442               0.0             0.0
# min     0.000000e+00       0.000000               0.0             0.0
# 25%     8.900000e+04       0.000000               0.0             0.0
# 50%     1.250000e+05    3000.000000               0.0             0.0
# 75%     1.790000e+05   16000.000000               0.0             0.0
# max     1.579000e+06  384500.000000               0.0             0.0
#
#        sale_percent
# count  61728.000000
# mean      37.588372
# std       23.294592
# min        0.000000
# 25%       23.000000
# 50%       33.000000
# 75%       45.000000
# max      100.000000

# %% [markdown]
# 3. DATA EXPLORATORY

# %%
#Import requirements library
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# 3.1. TOTAL SELLING BY DAY

# %%
#Create dataframe
sellingByDay = pd.DataFrame()
#Daily gross with onsite price
sellingByDay["onsite_original_price"] = newOrder.groupby("created_day")["onsite_original_price"].sum()
#Daily gross with selling price
sellingByDay["selling_price"] = newOrder.groupby("created_day")["selling_price"].sum()
#Daily gross with selling price
sellingByDay["shipping_fee"] = newOrder.groupby("created_day")["shipping_fee"].sum()

sellingByDay.head()
# Out:
#              onsite_original_price  selling_price  shipping_fee
# created_day
# 2019-07-01               175753000      139039400       9249126
# 2019-07-02               164233000      128637400       6530021
# 2019-07-03               218898000      170575700       9899283
# 2019-07-04               157886000      126265400       6768490
# 2019-07-05               223512000      172225700       9646238

# %%
#Plot onsite, selling price and shipping fee
plt.figure(figsize=(12, 8)) #Set figure size
sns.lineplot(data=sellingByDay, linewidth=3) #plot the data
plt.title("ONSITE PRICE, SELLING PRICE, SHIPPING FEE BY DAY", fontsize=16, fontweight="bold") #set title
plt.xlabel("CREATED DAY", fontsize=12, fontweight="bold") #set x axis title
plt.ylabel("VND", fontsize=12, fontweight="bold") #set y axis title
current_values = plt.gca().get_yticks() #get current labels
plt.savefig("ONSITE_SELLING_SHIPPING_FEE.png")
plt.show()

# %% [markdown]
# 3.2. TOTAL SELLING PRICE BY WEEKDAYS

# %%
sellingByWeekday = pd.DataFrame()
#Weekday gross with onsite price
sellingByWeekday["onsite_original_price"] = newOrder.groupby("weekday", sort=False)["onsite_original_price"].sum()
#Weekday gross with selling price
sellingByWeekday["selling_price"] = newOrder.groupby("weekday", sort=False)["selling_price"].sum()
#Weekday gross with selling price
sellingByWeekday["shipping_fee"] = newOrder.groupby("weekday", sort=False)["shipping_fee"].sum()

sellingByWeekday
# Out:
#            onsite_original_price  selling_price  shipping_fee
# weekday
# Monday                 961461000      744050900      41130098
# Tuesday               1054451000      773561370      43942214
# Wednesday             1474575000     1045902560      66613646
# Thursday              2110011000     1371083910      78998329
# Friday                6377397000     3541141700     380269296
# Sunday                1569531000     1168339210      48135057
# Saturday               940580000      706589430      31715932

# %%
#Plot onsite, selling price and shipping fee
plt.figure(figsize=(12, 8)) #Set figure size
sns.lineplot(data=sellingByWeekday, linewidth=3) #plot the data
plt.title("ONSITE PRICE, SELLING PRICE, SHIPPING FEE BY WEEKDAY", fontsize=16, fontweight="bold") #set title
plt.xlabel("WEEK DAY", fontsize=12, fontweight="bold") #set x axis title
plt.ylabel("VND", fontsize=12, fontweight="bold") #set y axis title
current_values = plt.gca().get_yticks() #get current labels
plt.savefig("ONSITE_SELLING_SHIPPING_FEE_WEEKDAY.png")
plt.show()

# %% [markdown]
# 3.3. QUANTITY IN DAY

# %%
#Create dataframe
quantityInDay = pd.DataFrame()
#Selling Item by day
quantityInDay["item_count"] = newOrder.groupby("created_day", sort=False)["item_quantity"].sum()
quantityInDay = quantityInDay.reset_index() #reset dataframe index
quantityInDay["created_day"] = quantityInDay["created_day"].dt.strftime('%m-%d') #change created_day format from %Y-%m-%d to %m-%d

quantityInDay
# Out:
#    created_day  item_count
# 0        07-01         663
# 1        07-02         592
# 2        07-03         831
# 3        07-04         603
# 4        07-05         857
# 5        07-07        2053
# 6        07-08         971
# 7        07-09        2585
# 8        07-10        3207
# 9        07-11        6248
# 10       07-12       35073
# 11       07-13        1017
# 12       07-14        1076
# 13       07-15         809
# 14       07-17        1463
# 15       07-18         542
# 16       07-19         695
# 17       07-20         584
# 18       07-21         552
# 19       07-22         460
# 20       07-23         455
# 21       07-24         618
# 22       07-25         615
# 23       07-27        1935
# 24       07-28        2349
# 25       07-29         859
# 26       07-30         914

# %%
#Plot selling item by day
plt.figure(figsize=(20, 8)) #set plot size
sns.barplot(data=quantityInDay, x="created_day", y="item_count") #bar plot
plt.title("TOTAL SELL ITEM BY DAY IN MONTH", fontsize=16, fontweight="bold") #set title
plt.xlabel("DAY IN MONTH", fontsize=12, fontweight="bold") #set x axis title
plt.ylabel("ITEM", fontsize=12, fontweight="bold") #set y axis title
plt.savefig("TOTAL_SELL_ITEM_BY_DAY_IN_MONTH.png")
plt.show()

# %% [markdown]
# 3.5. ITEM QUANTITY IN WEEKDAY

# %%
#Create dataframe
quantityInWeekDay = pd.DataFrame()

# %%
#Count total sell item by weekday
quantityInWeekDay["item_weekday"] = newOrder.groupby("weekday", sort=False)["item_quantity"].sum()
quantityInWeekDay = quantityInWeekDay.reset_index() #reset dataframe index
quantityInWeekDay
# Out:
#      weekday  item_weekday
# 0     Monday          3762
# 1    Tuesday          4546
# 2  Wednesday          6119
# 3   Thursday          8008
# 4     Friday         36625
# 5     Sunday          6030
# 6   Saturday          3536

# %%
#Plot total sell item by weekday
plt.figure(figsize=(12, 8)) #set plot size
sns.barplot(data=quantityInWeekDay, x="weekday", y="item_weekday")
plt.title("TOTAL ITEM SELL IN WEEKDAY", fontsize=16, fontweight="bold")
plt.xlabel("WEEKDAYS", fontsize=12, fontweight="bold")
plt.ylabel("ITEM", fontsize=12, fontweight="bold")
plt.savefig("TOTAL_SELL_ITEM_BY_WEEK_DAY.png")
plt.show()

# %% [markdown]
# 3.6. DISCOUNT EFFECT ON DAY IN MONTH GROSS

# %%
#Sale percent statistic
newOrder.sale_percent.describe()
# Out:
# count    61728.000000
# mean        37.588372
# std         23.294592
# min          0.000000
# 25%         23.000000
# 50%         33.000000
# 75%         45.000000
# max        100.000000
# Name: sale_percent, dtype: float64

# %%
def salePercentQuery(createdQuery):
    """Function to Query data by day"""
    #Create dataframe
    mostSalePercent = pd.DataFrame()
    #Query data created
    salePercent = newOrder.query(createdQuery)
    #Find out sale_percent has more than 1000 item
    mostSalePercent["count"] = salePercent["sale_percent"].value_counts()
    mostSalePercent = mostSalePercent.loc[mostSalePercent.values>1000]
    mostSalePercent = mostSalePercent.reset_index()
    return mostSalePercent

# %%
#Query data by day in 12
salePercent12 = salePercentQuery('created_day=="2019-07-12"')
salePercent12
# Out:
#    index  count
# 0   49.0   3464
# 1   40.0   2592
# 2   47.0   2519
# 3   99.0   2347
# 4   50.0   1714
# 5   43.0   1703
# 6  100.0   1004

# %%
#Query data created_day = 9 10 11 12
salePercent_d9 = newOrder.query('created_day=="2019-07-09"')

salePercent_d10 = newOrder.query('created_day=="2019-07-10"')
salePercent_d11 = newOrder.query('created_day=="2019-07-11"')
salePercent_d12 = newOrder.query('created_day=="2019-07-12"')


salePercent = pd.concat([salePercent_d9,salePercent_d10,salePercent_d11,salePercent_d12])

salePercent
# Out:
#        customer_unique_id    order_id  item_quantity created_day  \
# 6196                 4279  A000004798              1  2019-07-09
# 6197                 4280  A000004799              1  2019-07-09
# 6198                 4281  A000004800              1  2019-07-09
# 6199                 4281  A000004800              1  2019-07-09
# 6200                 4282  A000004801              1  2019-07-09
# ...                   ...         ...            ...         ...
# 47636               21092  A000026823              1  2019-07-12
# 47637               21688  A000026826              1  2019-07-12
# 47638               16680  A000019843              1  2019-07-12
# 47639               16680  A000019843              1  2019-07-12
# 47640               16682  A000019846              1  2019-07-12
#
#        onsite_original_price  selling_price  shipping_fee  voucher_platform  \
# 6196                  248000         169000             0                 0
# 6197                  159000         109000         41745                 0
# 6198                  150000           1000             0                 0
# 6199                  148000         109000             0                 0
# 6200                  238000         199000          3000                 0
# ...                      ...            ...           ...               ...
# 47636                 125000          75000             0                 0
# 47637                 135000          79000         21392                 0
# 47638                  85000          59000         15100                 0
# 47639                 205000           1000         15100                 0
# 47640                 195000          99000             0                 0
#
#        voucher_seller    payment_method order_status  weekday  sale_percent
# 6196                0  Airpay Wallet V2    COMPLETED  Tuesday          32.0
# 6197                0  Cash on Delivery    COMPLETED  Tuesday          31.0
# 6198                0  Airpay Wallet V2    CANCELLED  Tuesday          99.0
# 6199                0  Airpay Wallet V2    CANCELLED  Tuesday          26.0
# 6200                0  Cash on Delivery    COMPLETED  Tuesday          16.0
# ...               ...               ...          ...      ...           ...
# 47636               0  Cash on Delivery    COMPLETED   Friday          40.0
# 47637               0     Shopee Wallet    COMPLETED   Friday          41.0
# 47638               0  Cash on Delivery    COMPLETED   Friday          31.0
# 47639               0  Cash on Delivery    COMPLETED   Friday         100.0
# 47640               0  Cash on Delivery    CANCELLED   Friday          49.0
#
# [41445 rows x 13 columns]

# %%
#Find out sale_percent has more than 1000 item
mostSalePercent = pd.DataFrame()
mostSalePercent["count"] = salePercent["sale_percent"].value_counts()
mostSalePercent = mostSalePercent.loc[mostSalePercent.values>1000]
mostSalePercent = mostSalePercent.reset_index()
mostSalePercent
# Out:
#     index  count
# 0    49.0   3473
# 1    99.0   3033
# 2    40.0   2868
# 3    47.0   2666
# 4    43.0   2321
# 5    50.0   1722
# 6   100.0   1489
# 7    34.0   1480
# 8    36.0   1383
# 9    32.0   1350
# 10   35.0   1215
# 11   29.0   1200
# 12   30.0   1173
# 13   41.0   1117
# 14   27.0   1085

# %%
def barPlotSalePercent(df):
    plt.figure(figsize=(12, 8))
    sns.barplot(data=df, x="index", y="count")
    plt.title("DISCOUNT PERCENT HAS MORE THAN 1000 ITEMS", fontsize=16, fontweight="bold")
    plt.xlabel("PERCENT", fontsize=12, fontweight="bold")
    plt.ylabel("ITEM", fontsize=12, fontweight="bold")
    plt.savefig("DISCOUNT_HAS_MORE_THAN_1000.png")
    plt.show()

# %%
barPlotSalePercent(salePercent12)

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=mostSalePercent, x="index", y="count")
plt.title("DISCOUNT HAS MORE THAN 1000 ITEMS FROM 07/09 TO 07/12", fontsize=16, fontweight="bold")
plt.xlabel("PERCENT", fontsize=12, fontweight="bold")
plt.ylabel("ITEM", fontsize=12, fontweight="bold")
plt.savefig("DISCOUNT_HAS_MORE_THAN_1000_ITEMS_FROM_9_12.png")
plt.show()

# %% [markdown]
# 3.7. DISCOUNT EFFECT ON DAY IN WEEKDAY GROSS

# %%
#Sale percent has more than 1000 item on Friday
salePercentFri = salePercentQuery('weekday=="Friday"')
salePercentFri
# Out:
#    index  count
# 0   49.0   3464
# 1   40.0   2606
# 2   47.0   2519
# 3   99.0   2347
# 4   50.0   1714
# 5   43.0   1703
# 6  100.0   1007

# %%
barPlotSalePercent(salePercentFri)

# %% [markdown]
# 3.8. DOES PAYMENT METHOD AFFECT ORDER STATUS?

# %%
#Query data with order_status = COMPLETED
paymentCompleted = newOrder.query('order_status=="COMPLETED"')
paymentCompleted = paymentCompleted.filter(["payment_method", "order_status"])
paymentCompleted["payment_method"].value_counts()
# Out:
# Cash on Delivery                    43570
# Airpay GIRO                          2207
# Cybersource                          1732
# Airpay Wallet V2                     1199
# Shopee Wallet                         341
# Cybersource (new)                     209
# VN Airpay Ibanking (Techcombank)      109
# VN Airpay Ibanking (Vietcombank)      101
# VN Airpay Ibanking (VPbank)            75
# VN Airpay Ibanking (BIDV)              40
# VN Airpay Ibanking (Agribank)          32
# VN Airpay Ibanking (ACB)               32
# VN Airpay Ibanking (Vietinbank)        24
# VN Airpay Ibanking (TPbank)            15
# VN Airpay Ibanking (DongAbank)         12
# VN Airpay Ibanking (Sacombank)          4
# VN Airpay Ibanking (MB)                 4
# VN Airpay Ibanking (HDbank)             4
# VN Airpay Ibanking (OCB)                3
# VN Airpay Ibanking (SHB)                3
# VN Airpay Ibanking (SEAB)               1
# Name: payment_method, dtype: int64

# %%
plt.figure(figsize=(12, 8))
sns.countplot(y="payment_method",data=paymentCompleted, order=paymentCompleted["payment_method"].value_counts().index)
plt.title('COUNTS OF PAYMENT METHOD (COMPLETED)', fontsize=16, fontweight='bold')
plt.xlabel("")
plt.ylabel("PAYMENT METHOD", fontsize=12, fontweight='bold')
plt.savefig("COUNTS_OF_PAYMENT_METHOD_COMPLETED_.png", bbox_inches = 'tight')
plt.show()

# %%
#Query data with order_status = CANCELLED
paymentCancelled = newOrder.query('order_status == "CANCELLED"')
paymentCancelled = paymentCancelled.filter(["payment_method", "order_status"])
paymentCancelled["payment_method"].value_counts()
# Out:
# Cash on Delivery                    10418
# Airpay GIRO                           597
# VN Airpay Ibanking (Vietcombank)      207
# Airpay Wallet V2                      168
# VN Airpay Ibanking (BIDV)              84
# VN Airpay Ibanking (Vietinbank)        71
# VN Airpay Ibanking (Agribank)          61
# VN Airpay Ibanking (Techcombank)       59
# Cybersource                            51
# Cybersource (new)                      37
# VN Airpay Ibanking (VPbank)            36
# VN Airpay Ibanking (Sacombank)         32
# VN Airpay Ibanking (ACB)               31
# VN Airpay Ibanking (DongAbank)         27
# Shopee Wallet                          25
# VN Airpay Ibanking (MSbank)            22
# VN Airpay Ibanking (MB)                22
# VN Airpay Ibanking (TPbank)            14
# VN Airpay Ibanking (NCB)                7
# VN Airpay Ibanking (OCB)                7
# VN Airpay Ibanking (Eximbank)           6
# VN Airpay Ibanking (Oceanbank)          6
# VN Airpay Ibanking (VIB)                6
# VN Airpay Ibanking (Indovina)           3
# VN Airpay Ibanking (HDbank)             3
# VN Airpay Ibanking (SEAB)               3
# VN Airpay Ibanking (SHB)                3
# VN Airpay Ibanking (ABB)                1
# VN Airpay Ibanking (LPB)                1
# VN Airpay Ibanking (SGB)                1
# VN Airpay Ibanking (PBVN)               1
# VN Airpay Ibanking (SCB)                1
# Name: payment_method, dtype: int64

# %%
plt.figure(figsize=(12, 8))
sns.countplot(y="payment_method",data=paymentCancelled, order=paymentCancelled["payment_method"].value_counts().index)
plt.title('COUNTS OF PAYMENT METHOD (CANCELLED)', fontsize=16, fontweight='bold')
plt.xlabel("")
plt.ylabel("PAYMENT METHOD", fontsize=12, fontweight='bold')
plt.savefig("COUNTS_OF_PAYMENT_METHOD_CANCELLED.png", bbox_inches = 'tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-63ee1b45796e> in <module>
#       1 plt.figure(figsize=(12, 8))
# ----> 2 sns.countplot(y="payment_method",data=paymentCancelled, order=paymentCancelled["payment_method"].value_counts().index)
#       3 plt.title('COUNTS OF PAYMENT METHOD (CANCELLED)', fontsize=16, fontweight='bold')
#       4 plt.xlabel("")
#       5 plt.ylabel("PAYMENT METHOD", fontsize=12, fontweight='bold')
#
# NameError: name 'paymentCancelled' is not defined

# %% [markdown]
# 3.9. ORDER CANCELLED RATIO AND SHIPPING FEE

# %%
#Create dataframe
orderRatio = pd.DataFrame()
#Query data with 'order_status=="COMPLETED"'
orderRatioCompleted = newOrder.query('order_status=="COMPLETED"')
orderRatioCompleted = orderRatioCompleted.filter(["shipping_fee", "payment_method", "order_status"])
orderRatio["completed"] = orderRatioCompleted["payment_method"].value_counts()
orderRatio["avg_fee_completed"] = orderRatioCompleted.groupby("payment_method")["shipping_fee"].mean()
#Query data with 'order_status=="CANCELLED"'
orderRatioCancelled = newOrder.query('order_status=="CANCELLED"')
orderRatioCancelled = orderRatioCancelled.filter(["shipping_fee", "payment_method", "order_status"])
orderRatio["cancelled"] = orderRatioCancelled["payment_method"].value_counts()
orderRatio["avg_fee_cancelled"] = orderRatioCancelled.groupby("payment_method")["shipping_fee"].mean()

# %%
#Compute order ratio
orderRatio["ratio"] = round(orderRatio["cancelled"]/orderRatio["completed"]*100)
orderRatio = orderRatio.reset_index()
orderRatio.rename(columns={"index":"payment_method"}, inplace=True)
orderRatio
# Out:
#                       payment_method  completed  avg_fee_completed  cancelled  \
# 0                   Cash on Delivery      43570       10800.908813      10418
# 1                        Airpay GIRO       2207        4888.869959        597
# 2                        Cybersource       1732        8193.934758         51
# 3                   Airpay Wallet V2       1199        4413.326105        168
# 4                      Shopee Wallet        341        8701.730205         25
# 5                  Cybersource (new)        209        4653.622010         37
# 6   VN Airpay Ibanking (Techcombank)        109        8712.311927         59
# 7   VN Airpay Ibanking (Vietcombank)        101        6965.455446        207
# 8        VN Airpay Ibanking (VPbank)         75       11205.280000         36
# 9          VN Airpay Ibanking (BIDV)         40       16104.300000         84
# 10     VN Airpay Ibanking (Agribank)         32        8294.625000         61
# 11          VN Airpay Ibanking (ACB)         32        1941.812500         31
# 12   VN Airpay Ibanking (Vietinbank)         24       12472.375000         71
# 13       VN Airpay Ibanking (TPbank)         15       10883.333333         14
# 14    VN Airpay Ibanking (DongAbank)         12         416.666667         27
# 15    VN Airpay Ibanking (Sacombank)          4        7164.750000         32
# 16           VN Airpay Ibanking (MB)          4        5000.000000         22
# 17       VN Airpay Ibanking (HDbank)          4        1625.000000          3
# 18          VN Airpay Ibanking (OCB)          3       17022.000000          7
# 19          VN Airpay Ibanking (SHB)          3       40226.333333          3
# 20         VN Airpay Ibanking (SEAB)          1       10000.000000          3
#
#     avg_fee_cancelled  ratio
# 0        15555.398829   24.0
# 1         7815.058626   27.0
# 2        24195.254902    3.0
# 3        18939.535714   14.0
# 4        15949.520000    7.0
# 5         7275.378378   18.0
# 6        10780.966102   54.0
# 7        13270.246377  205.0
# 8        16854.750000   48.0
# 9        14159.797619  210.0
# 10       11174.557377  191.0
# 11       10409.935484   97.0
# 12       22781.140845  296.0
# 13       32380.142857   93.0
# 14       11599.037037  225.0
# 15        8442.781250  800.0
# 16        8856.227273  550.0
# 17       10325.666667   75.0
# 18       19771.428571  233.0
# 19       24209.333333  100.0
# 20       10330.666667  300.0

# %%
plt.figure(figsize=(12, 8))
sns.pointplot(data=orderRatio, x="payment_method", y="ratio", join=False)
plt.title("CANCELLED PERCENT", fontsize=16, fontweight='bold')
plt.xlabel("PAYMENT METHOD", fontsize=12, fontweight='bold')
plt.ylabel("CANCELLED RATIO (%)", fontsize=12, fontweight='bold')
plt.xticks(rotation=75)
plt.savefig("CANCELLED_PERCENT.png", bbox_inches = 'tight')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(data=orderRatio, x="payment_method", y="avg_fee_completed", markers=True, dashes=False, linewidth=3)
sns.lineplot(data=orderRatio, x="payment_method", y="avg_fee_cancelled", markers=True, dashes=False, linewidth=3)
plt.title("SHIPPING FEE WITH EACH PAYMENT METHOD (COMPLETED AND CANCELLED)", fontsize=16, fontweight='bold')
plt.xlabel("PAYMENT METHOD", fontsize=12, fontweight='bold')
plt.ylabel("SHIPPING FEE (VND)", fontsize=12, fontweight='bold')
plt.xticks(rotation=75)
plt.legend(['Completed', 'Cancelled'])
plt.savefig("SHIPPING_FEE.png", bbox_inches = 'tight')
plt.show()

# %%
meanFee = orderRatioCancelled.groupby("payment_method")["shipping_fee"].mean()
meanFee
# Out:
# payment_method
# Airpay GIRO                          7815.058626
# Airpay Wallet V2                    18939.535714
# Cash on Delivery                    15555.398829
# Cybersource                         24195.254902
# Cybersource (new)                    7275.378378
# Shopee Wallet                       15949.520000
# VN Airpay Ibanking (ABB)            29645.000000
# VN Airpay Ibanking (ACB)            10409.935484
# VN Airpay Ibanking (Agribank)       11174.557377
# VN Airpay Ibanking (BIDV)           14159.797619
# VN Airpay Ibanking (DongAbank)      11599.037037
# VN Airpay Ibanking (Eximbank)        7719.833333
# VN Airpay Ibanking (HDbank)         10325.666667
# VN Airpay Ibanking (Indovina)        2000.000000
# VN Airpay Ibanking (LPB)                0.000000
# VN Airpay Ibanking (MB)              8856.227273
# VN Airpay Ibanking (MSbank)         10615.454545
# VN Airpay Ibanking (NCB)            15247.857143
# VN Airpay Ibanking (OCB)            19771.428571
# VN Airpay Ibanking (Oceanbank)      18525.000000
# VN Airpay Ibanking (PBVN)               0.000000
# VN Airpay Ibanking (SCB)                0.000000
# VN Airpay Ibanking (SEAB)           10330.666667
# VN Airpay Ibanking (SGB)            14927.000000
# VN Airpay Ibanking (SHB)            24209.333333
# VN Airpay Ibanking (Sacombank)       8442.781250
# VN Airpay Ibanking (TPbank)         32380.142857
# VN Airpay Ibanking (Techcombank)    10780.966102
# VN Airpay Ibanking (VIB)            27797.500000
# VN Airpay Ibanking (VPbank)         16854.750000
# VN Airpay Ibanking (Vietcombank)    13270.246377
# VN Airpay Ibanking (Vietinbank)     22781.140845
# Name: shipping_fee, dtype: float64
